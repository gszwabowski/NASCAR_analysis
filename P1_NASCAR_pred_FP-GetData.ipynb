# %% [markdown]
# # Part 1: Get Races from 2017 - 2022

# %% [markdown]
# ## Race Results

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

BASE_URL = 'https://racing-reference.info'
years = range(2017, 2023)
cup_results = [requests.get(BASE_URL + f'/season-stats/{year}/W') for year in years]
set([r.status_code for r in cup_results])
# Out:
# {200}

# %%
race_anchors = []
href_regex = re.compile('/race-results/.*/W')
race_dates = []

for c in cup_results:
    race_anchors.extend(BeautifulSoup(c.text, 'lxml').find_all(href=href_regex))
    result = BeautifulSoup(c.text, 'lxml').find_all("div", {"class": "date W"})
    for res in result:
        race_dates.append(res.text)

# %%
len(race_dates)
# Out:
# 216

# %%
# convert race_dates to datetime objs
race_dates_dt = []
from datetime import datetime
for date in race_dates:
    race_dates_dt.append(datetime.strptime(date, '%m/%d/%y'))

# %%
len(race_anchors)
# Out:
# 216

# %%
races = [requests.get(a.attrs['href']) for a in race_anchors]

# %%
set([r.status_code for r in races])
# Out:
# {200}

# %%
# display first race
pd.read_html(races[0].text, match='Sponsor / Owner', header=0)[-1]
# Out:
#     Pos  St   #                Driver  \
# 0     1   8  41            Kurt Busch
# 1     2  36  21           Ryan Blaney
# 2     3  38  47     A.J. Allmendinger
# 3     4  13  43         Aric Almirola
# 4     5  33  27           Paul Menard
# 5     6  15  22           Joey Logano
# 6     7  26   5           Kasey Kahne
# 7     8  30  15       Michael Waltrip
# 8     9  25  32      Matt DiBenedetto
# 9    10  11   6          Trevor Bayne
# 10   11  39  75       Brendan Gaughan
# 11   12  16  42           Kyle Larson
# 12   13  35  78     Martin Truex, Jr.
# 13   14   1  24         Chase Elliott
# 14   15  22  95      Michael McDowell
# 15   16  27  34        Landon Cassill
# 16   17   4  11          Denny Hamlin
# 17   18  17  72            Cole Whitt
# 18   19  10   3         Austin Dillon
# 19   20  40   7        Elliott Sadler
# 20   21  14  31           Ryan Newman
# 21   22   5   4         Kevin Harvick
# 22   23  29  23             Joey Gase
# 23   24  31  83          Corey LaJoie
# 24   25  20  38           David Ragan
# 25   26  32  33     Jeffrey Earnhardt
# 26   27   7   2       Brad Keselowski
# 27   28   3   1        Jamie McMurray
# 28   29  19  19         Daniel Suarez
# 29   30  18  13             Ty Dillon
# 30   31  23  17  Ricky Stenhouse, Jr.
# 31   32   6  14          Clint Bowyer
# 32   33  12  10        Danica Patrick
# 33   34  24  48        Jimmie Johnson
# 34   35  37  37        Chris Buescher
# 35   36  28  96       D.J. Kennington
# 36   37   2  88   Dale Earnhardt, Jr.
# 37   38  21  18            Kyle Busch
# 38   39  34  77            Erik Jones
# 39   40   9  20          Matt Kenseth
#
#                                       Sponsor / Owner        Car  Laps  \
# 0   Haas Automation / Monster Energy (Stewart Haas...       Ford   200
# 1   Motorcraft / Quick Lane Tire & Auto Center (Wo...       Ford   200
# 2   Kroger ClickList / Stouffer's / Cheez-It (JTG-...  Chevrolet   200
# 3        Smithfield Foods (Richard Petty Motorsports)       Ford   200
# 4                  Menards / Peak (Richard Childress)  Chevrolet   200
# 5                     Shell / Pennzoil (Roger Penske)       Ford   200
# 6                   Farmers Insurance (Rick Hendrick)  Chevrolet   200
# 7             Aaron's "Thanks, Mikey!" (Jay Robinson)     Toyota   200
# 8           E.J. Wade Foundation (Archie St. Hilaire)       Ford   200
# 9                               AdvoCare (Jack Roush)       Ford   200
# 10         Beard Oil Distributing (Beard Motorsports)  Chevrolet   200
# 11                 Target / Cottonelle (Chip Ganassi)  Chevrolet   200
# 12     Bass Pro Shops / Tracker Boats (Barney Visser)     Toyota   200
# 13                    NAPA Auto Parts (Rick Hendrick)  Chevrolet   200
# 14               K-LOVE Radio (Leavine Family Racing)  Chevrolet   200
# 15                  Love's Travel Stops (Bob Jenkins)       Ford   199
# 16                          FedEx Express (Joe Gibbs)     Toyota   199
# 17                       Florida Lottery (Mark Smith)       Ford   199
# 18                            Dow (Richard Childress)  Chevrolet   199
# 19                 Golden Corral (Tommy Baldwin, Jr.)  Chevrolet   199
# 20                    Caterpillar (Richard Childress)  Chevrolet   198
# 21                 Jimmy John's (Stewart Haas Racing)       Ford   197
# 22                  Best Home Furnishings (BK Racing)     Toyota   196
# 23                      Dustless Blasting (BK Racing)     Toyota   193
# 24             Camping World / Good Sam (Bob Jenkins)       Ford   188
# 25                                 Starter (Joe Falk)  Chevrolet   145
# 26                         Miller Lite (Roger Penske)       Ford   143
# 27                 Cessna / McDonald's (Chip Ganassi)  Chevrolet   141
# 28                Arris High-Speed Modems (Joe Gibbs)     Toyota   141
# 29                             GEICO (Germain Racing)  Chevrolet   140
# 30                     Fastenal / Wypall (Jack Roush)       Ford   133
# 31                      Mobil 1 (Stewart Haas Racing)       Ford   128
# 32                 Aspen Dental (Stewart Haas Racing)       Ford   128
# 33                             Lowe's (Rick Hendrick)  Chevrolet   127
# 34  Cottonelle MegaRoll / Scott Products (JTG-Daug...  Chevrolet   127
# 35       Lordco Auto Parts / Castrol (Gaunt Brothers)     Toyota   127
# 36               Nationwide Insurance (Rick Hendrick)  Chevrolet   106
# 37                                  M&M's (Joe Gibbs)     Toyota   103
# 38       5-hour Energy Extra Strength (Barney Visser)     Toyota   103
# 39                        DeWalt FlexVolt (Joe Gibbs)     Toyota   103
#
#      Status  Led  Pts  PPts
# 0   running    1   48     5
# 1   running    2   44     0
# 2   running    2   39     0
# 3   running    2   33     0
# 4   running    0   32     0
# 5   running   16   40     0
# 6   running    7   30     0
# 7   running    0   29     0
# 8   running    0   28     0
# 9   running    0   27     0
# 10  running    0    0     0
# 11  running   16   33     0
# 12  running    2   24     0
# 13  running   39   23     0
# 14  running    0   22     0
# 15  running    0   21     0
# 16  running    0   23     0
# 17  running    3   19     0
# 18  running    7   18     0
# 19  running    5    0     0
# 20  running    0   18     0
# 21  running   50   34     1
# 22  running    0    0     0
# 23  running    0   13     0
# 24  running    0   12     0
# 25    crash    0   11     0
# 26    crash    2   24     0
# 27    crash   13   13     0
# 28    crash    0    8     0
# 29    crash    0    7     0
# 30    crash    0    6     0
# 31    crash    0    9     0
# 32    crash    0   11     0
# 33    crash    7    5     0
# 34    crash    0    2     0
# 35    crash    0    1     0
# 36    crash    8    7     0
# 37    crash   18   11     1
# 38    crash    0    1     0
# 39    crash    0    1     0

# %%
#create a dictionary containing a list of each year's tracks
trackdata = []
years = range(2017, 2023)
for x in cup_results:
    trackdata.append(BeautifulSoup(x.text, 'lxml').find_all(class_='track W'))

tracks = []
for group in trackdata:
    yeartracks = []
    for tag in group:
        yeartracks.append(tag.text.strip())
    tracks.append(yeartracks)
    
trackdict = dict(zip(years, tracks))

# %%
trackdict
# Out:
# {2017: ['Daytona',
#   'Atlanta',
#   'Las Vegas',
#   'Phoenix',
#   'Fontana',
#   'Martinsville',
#   'Fort Worth',
#   'Bristol',
#   'Richmond',
#   'Talladega',
#   'Kansas',
#   'Charlotte',
#   'Dover',
#   'Pocono',
#   'Michigan',
#   'Sonoma',
#   'Daytona',
#   'Kentucky',
#   'Loudon',
#   'Indianapolis',
#   'Pocono',
#   'Watkins Glen',
#   'Michigan',
#   'Bristol',
#   'Darlington',
#   'Richmond',
#   'Chicago',
#   'Loudon',
#   'Dover',
#   'Charlotte',
#   'Talladega',
#   'Kansas',
#   'Martinsville',
#   'Fort Worth',
#   'Phoenix',
#   'Homestead'],
#  2018: ['Daytona',
#   'Atlanta',
#   'Las Vegas',
#   'Phoenix',
#   'Fontana',
#   'Martinsville',
#   'Fort Worth',
#   'Bristol',
#   'Richmond',
#   'Talladega',
#   'Dover',
#   'Kansas',
#   'Charlotte',
#   'Pocono',
#   'Michigan',
#   'Sonoma',
#   'Chicago',
#   'Daytona',
#   'Kentucky',
#   'Loudon',
#   'Pocono',
#   'Watkins Glen',
#   'Michigan',
#   'Bristol',
#   'Darlington',
#   'Indianapolis',
#   'Las Vegas',
#   'Richmond',
#   'Charlotte (Road)',
#   'Dover',
#   'Talladega',
#   'Kansas',
#   'Martinsville',
#   'Fort Worth',
#   'Phoenix',
#   'Homestead'],
#  2019: ['Daytona',
#   'Atlanta',
#   'Las Vegas',
#   'Phoenix',
#   'Fontana',
#   'Martinsville',
#   'Fort Worth',
#   'Bristol',
#   'Richmond',
#   'Talladega',
#   'Dover',
#   'Kansas',
#   'Charlotte',
#   'Pocono',
#   'Michigan',
#   'Sonoma',
#   'Chicago',
#   'Daytona',
#   'Kentucky',
#   'Loudon',
#   'Pocono',
#   'Watkins Glen',
#   'Michigan',
#   'Bristol',
#   'Darlington',
#   'Indianapolis',
#   'Las Vegas',
#   'Richmond',
#   'Charlotte (Road)',
#   'Dover',
#   'Talladega',
#   'Kansas',
#   'Martinsville',
#   'Fort Worth',
#   'Phoenix',
#   'Homestead'],
#  2020: ['Daytona',
#   'Las Vegas',
#   'Fontana',
#   'Phoenix',
#   'Darlington',
#   'Darlington',
#   'Charlotte',
#   'Charlotte',
#   'Bristol',
#   'Atlanta',
#   'Martinsville',
#   'Homestead',
#   'Talladega',
#   'Pocono',
#   'Pocono',
#   'Indianapolis',
#   'Kentucky',
#   'Fort Worth',
#   'Kansas',
#   'Loudon',
#   'Michigan',
#   'Michigan',
#   'Daytona (Road)',
#   'Dover',
#   'Dover',
#   'Daytona',
#   'Darlington',
#   'Richmond',
#   'Bristol',
#   'Las Vegas',
#   'Talladega',
#   'Charlotte (Road)',
#   'Kansas',
#   'Fort Worth',
#   'Martinsville',
#   'Phoenix'],
#  2021: ['Daytona',
#   'Daytona (Road)',
#   'Homestead',
#   'Las Vegas',
#   'Phoenix',
#   'Atlanta',
#   'Bristol (Dirt)',
#   'Martinsville',
#   'Richmond',
#   'Talladega',
#   'Kansas',
#   'Darlington',
#   'Dover',
#   'Austin',
#   'Charlotte',
#   'Sonoma',
#   'Nashville',
#   'Pocono',
#   'Pocono',
#   'Elkhart Lake',
#   'Atlanta',
#   'Loudon',
#   'Watkins Glen',
#   'Indianapolis G.P.',
#   'Michigan',
#   'Daytona',
#   'Darlington',
#   'Richmond',
#   'Bristol',
#   'Las Vegas',
#   'Talladega',
#   'Charlotte (Road)',
#   'Fort Worth',
#   'Kansas',
#   'Martinsville',
#   'Phoenix'],
#  2022: ['Daytona',
#   'Fontana',
#   'Las Vegas',
#   'Phoenix',
#   'Atlanta',
#   'Austin',
#   'Richmond',
#   'Martinsville',
#   'Bristol (Dirt)',
#   'Talladega',
#   'Dover',
#   'Darlington',
#   'Kansas',
#   'Charlotte',
#   'Gateway',
#   'Sonoma',
#   'Nashville',
#   'Elkhart Lake',
#   'Atlanta',
#   'Loudon',
#   'Pocono',
#   'Indianapolis G.P.',
#   'Michigan',
#   'Richmond',
#   'Watkins Glen',
#   'Daytona',
#   'Darlington',
#   'Kansas',
#   'Bristol',
#   'Fort Worth',
#   'Talladega',
#   'Charlotte (Road)',
#   'Las Vegas',
#   'Homestead',
#   'Martinsville',
#   'Phoenix']}

# %%
len(races)
# Out:
# 216

# %%
#flatten track list
tracklst = [x for l in tracks for x in l]

#create empty dataframe to put race data into
racedata = pd.DataFrame(columns = [
 'Pos',
 'St',
 '#',
 'Driver',
 'Sponsor / Owner',
 'Car',
 'Laps',
 'Status',
 'Led',
 'Pts',
 'PPts',
 'Track'])

#create dataframe with data for all races from 2017-2021
for i in range(len(races)):
    race = pd.read_html(races[i].text, match='Sponsor / Owner', header=0)[-1]
    race['Track'] = tracklst[i]
    race['Date'] = race_dates[i]
    race['Date_dtobj'] = race_dates_dt[i]
    racedata = pd.concat([racedata, race])
    #print(race)
    
print(racedata)
# Out:
#    Pos  St   #                Driver  \
# 0    1   8  41            Kurt Busch
# 1    2  36  21           Ryan Blaney
# 2    3  38  47     A.J. Allmendinger
# 3    4  13  43         Aric Almirola
# 4    5  33  27           Paul Menard
# ..  ..  ..  ..                   ...
# 31  32  29  47  Ricky Stenhouse, Jr.
# 32  33  35  15      Garrett Smithley
# 33  34  24  48           Alex Bowman
# 34  35  18   6       Brad Keselowski
# 35  36  36  77        Landon Cassill
#
#                                       Sponsor / Owner        Car Laps  \
# 0   Haas Automation / Monster Energy (Stewart Haas...       Ford  200
# 1   Motorcraft / Quick Lane Tire & Auto Center (Wo...       Ford  200
# 2   Kroger ClickList / Stouffer's / Cheez-It (JTG-...  Chevrolet  200
# 3        Smithfield Foods (Richard Petty Motorsports)       Ford  200
# 4                  Menards / Peak (Richard Childress)  Chevrolet  200
# ..                                                ...        ...  ...
# 31        Fry's/ Nature Valley (JTG-Daugherty Racing)  Chevrolet  307
# 32                        Jacob Companies (Rick Ware)       Ford  304
# 33                               Ally (Rick Hendrick)  Chevrolet  304
# 34                     Kohler Generators (Jack Roush)       Ford  270
# 35     Mutoh/General Formulations (Spire Motorsports)  Chevrolet   84
#
#         Status Led Pts PPts    Track      Date Date_dtobj
# 0      running   1  48    5  Daytona  02/26/17 2017-02-26
# 1      running   2  44    0  Daytona  02/26/17 2017-02-26
# 2      running   2  39    0  Daytona  02/26/17 2017-02-26
# 3      running   2  33    0  Daytona  02/26/17 2017-02-26
# 4      running   0  32    0  Daytona  02/26/17 2017-02-26
# ..         ...  ..  ..  ...      ...       ...        ...
# 31     running   0   5    0  Phoenix  11/06/22 2022-11-06
# 32     running   0   0    0  Phoenix  11/06/22 2022-11-06
# 33     running   1   3    0  Phoenix  11/06/22 2022-11-06
# 34  electrical   0   2    0  Phoenix  11/06/22 2022-11-06
# 35       crash   0   0    0  Phoenix  11/06/22 2022-11-06
#
# [8312 rows x 14 columns]

# %%
# dump racedata to csv
racedata.to_csv('data/racedata_2017-2022.csv')

# %% [markdown]
# ## Loop Data

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
years = range(2017, 2023)
racenums = range(1,37,1)
frames = []
race_id = 0

# loop through each year and racenumber and get loop data
for year in years:
    for num in racenums:
        race_id += 1
        if len(str(num)) == 1: # if race num. 1-9
            newnum = '0' + str(num)
            # get loop data for year/num combo
            url = 'https://www.racing-reference.info/loopdata/' + str(year) + '-' + newnum + '/W/'
            print(f'getting loop data for race {newnum} in {year} ({url})')
            response = requests.get(url)
            df = pd.read_html(response.text)[4].drop([0,1,2])
            df = df.reset_index(drop = True)
            df.columns = ['Driver', 'Start', 'Mid Race', 'Finish', 'High Pos.', 'Low Pos.', 'Avg. Pos.', 'Pass Diff.', 'Green Flag Passes', 'Green Flag Times Passed', 'Quality Passes', 'Pct. Quality Passes', 'Fastest Lap', 'Top 15 Laps', 'Pct. Top 15 Laps', 'Laps Led', 'Pct. Laps Led', 'Total Laps', 'DRIVER RATING']
            df['race_ID'] = race_id
            frames.append(df)
        else: # race num. 10-38
            # get loop data for year/num combo
            url = 'https://www.racing-reference.info/loopdata/' + str(year) + '-' + str(num) + '/W/'
            print(f'getting loop data for race {num} in {year} ({url})')
            response = requests.get(f'https://www.racing-reference.info/loopdata/{year}-{num}/W/')
            df = pd.read_html(response.text)[4].drop([0,1,2])
            df = df.reset_index(drop = True)
            df.columns = ['Driver', 'Start', 'Mid Race', 'Finish', 'High Pos.', 'Low Pos.', 'Avg. Pos.', 'Pass Diff.', 'Green Flag Passes', 'Green Flag Times Passed', 'Quality Passes', 'Pct. Quality Passes', 'Fastest Lap', 'Top 15 Laps', 'Pct. Top 15 Laps', 'Laps Led', 'Pct. Laps Led', 'Total Laps', 'DRIVER RATING']
            df['race_ID'] = race_id
            frames.append(df)
# Out:
# getting loop data for race 01 in 2017 (https://www.racing-reference.info/loopdata/2017-01/W/)
# getting loop data for race 02 in 2017 (https://www.racing-reference.info/loopdata/2017-02/W/)
# getting loop data for race 03 in 2017 (https://www.racing-reference.info/loopdata/2017-03/W/)
# getting loop data for race 04 in 2017 (https://www.racing-reference.info/loopdata/2017-04/W/)
# getting loop data for race 05 in 2017 (https://www.racing-reference.info/loopdata/2017-05/W/)
# getting loop data for race 06 in 2017 (https://www.racing-reference.info/loopdata/2017-06/W/)
# getting loop data for race 07 in 2017 (https://www.racing-reference.info/loopdata/2017-07/W/)
# getting loop data for race 08 in 2017 (https://www.racing-reference.info/loopdata/2017-08/W/)
# getting loop data for race 09 in 2017 (https://www.racing-reference.info/loopdata/2017-09/W/)
# getting loop data for race 10 in 2017 (https://www.racing-reference.info/loopdata/2017-10/W/)
# getting loop data for race 11 in 2017 (https://www.racing-reference.info/loopdata/2017-11/W/)
# getting loop data for race 12 in 2017 (https://www.racing-reference.info/loopdata/2017-12/W/)
# getting loop data for race 13 in 2017 (https://www.racing-reference.info/loopdata/2017-13/W/)
# getting loop data for race 14 in 2017 (https://www.racing-reference.info/loopdata/2017-14/W/)
# getting loop data for race 15 in 2017 (https://www.racing-reference.info/loopdata/2017-15/W/)
# getting loop data for race 16 in 2017 (https://www.racing-reference.info/loopdata/2017-16/W/)
# getting loop data for race 17 in 2017 (https://www.racing-reference.info/loopdata/2017-17/W/)
# getting loop data for race 18 in 2017 (https://www.racing-reference.info/loopdata/2017-18/W/)
# getting loop data for race 19 in 2017 (https://www.racing-reference.info/loopdata/2017-19/W/)
# getting loop data for race 20 in 2017 (https://www.racing-reference.info/loopdata/2017-20/W/)
# getting loop data for race 21 in 2017 (https://www.racing-reference.info/loopdata/2017-21/W/)
# getting loop data for race 22 in 2017 (https://www.racing-reference.info/loopdata/2017-22/W/)
# getting loop data for race 23 in 2017 (https://www.racing-reference.info/loopdata/2017-23/W/)
# getting loop data for race 24 in 2017 (https://www.racing-reference.info/loopdata/2017-24/W/)
# getting loop data for race 25 in 2017 (https://www.racing-reference.info/loopdata/2017-25/W/)
# getting loop data for race 26 in 2017 (https://www.racing-reference.info/loopdata/2017-26/W/)
# getting loop data for race 27 in 2017 (https://www.racing-reference.info/loopdata/2017-27/W/)
# getting loop data for race 28 in 2017 (https://www.racing-reference.info/loopdata/2017-28/W/)
# getting loop data for race 29 in 2017 (https://www.racing-reference.info/loopdata/2017-29/W/)
# getting loop data for race 30 in 2017 (https://www.racing-reference.info/loopdata/2017-30/W/)
# getting loop data for race 31 in 2017 (https://www.racing-reference.info/loopdata/2017-31/W/)
# getting loop data for race 32 in 2017 (https://www.racing-reference.info/loopdata/2017-32/W/)
# getting loop data for race 33 in 2017 (https://www.racing-reference.info/loopdata/2017-33/W/)
# getting loop data for race 34 in 2017 (https://www.racing-reference.info/loopdata/2017-34/W/)
# getting loop data for race 35 in 2017 (https://www.racing-reference.info/loopdata/2017-35/W/)
# getting loop data for race 36 in 2017 (https://www.racing-reference.info/loopdata/2017-36/W/)
# getting loop data for race 01 in 2018 (https://www.racing-reference.info/loopdata/2018-01/W/)
# getting loop data for race 02 in 2018 (https://www.racing-reference.info/loopdata/2018-02/W/)
# getting loop data for race 03 in 2018 (https://www.racing-reference.info/loopdata/2018-03/W/)
# getting loop data for race 04 in 2018 (https://www.racing-reference.info/loopdata/2018-04/W/)
# getting loop data for race 05 in 2018 (https://www.racing-reference.info/loopdata/2018-05/W/)
# getting loop data for race 06 in 2018 (https://www.racing-reference.info/loopdata/2018-06/W/)
# getting loop data for race 07 in 2018 (https://www.racing-reference.info/loopdata/2018-07/W/)
# getting loop data for race 08 in 2018 (https://www.racing-reference.info/loopdata/2018-08/W/)
# getting loop data for race 09 in 2018 (https://www.racing-reference.info/loopdata/2018-09/W/)
# getting loop data for race 10 in 2018 (https://www.racing-reference.info/loopdata/2018-10/W/)
# getting loop data for race 11 in 2018 (https://www.racing-reference.info/loopdata/2018-11/W/)
# getting loop data for race 12 in 2018 (https://www.racing-reference.info/loopdata/2018-12/W/)
# getting loop data for race 13 in 2018 (https://www.racing-reference.info/loopdata/2018-13/W/)
# getting loop data for race 14 in 2018 (https://www.racing-reference.info/loopdata/2018-14/W/)
# getting loop data for race 15 in 2018 (https://www.racing-reference.info/loopdata/2018-15/W/)
# getting loop data for race 16 in 2018 (https://www.racing-reference.info/loopdata/2018-16/W/)
# getting loop data for race 17 in 2018 (https://www.racing-reference.info/loopdata/2018-17/W/)
# getting loop data for race 18 in 2018 (https://www.racing-reference.info/loopdata/2018-18/W/)
# getting loop data for race 19 in 2018 (https://www.racing-reference.info/loopdata/2018-19/W/)
# getting loop data for race 20 in 2018 (https://www.racing-reference.info/loopdata/2018-20/W/)
# getting loop data for race 21 in 2018 (https://www.racing-reference.info/loopdata/2018-21/W/)
# getting loop data for race 22 in 2018 (https://www.racing-reference.info/loopdata/2018-22/W/)
# getting loop data for race 23 in 2018 (https://www.racing-reference.info/loopdata/2018-23/W/)
# getting loop data for race 24 in 2018 (https://www.racing-reference.info/loopdata/2018-24/W/)
# getting loop data for race 25 in 2018 (https://www.racing-reference.info/loopdata/2018-25/W/)
# getting loop data for race 26 in 2018 (https://www.racing-reference.info/loopdata/2018-26/W/)
# getting loop data for race 27 in 2018 (https://www.racing-reference.info/loopdata/2018-27/W/)
# getting loop data for race 28 in 2018 (https://www.racing-reference.info/loopdata/2018-28/W/)
# getting loop data for race 29 in 2018 (https://www.racing-reference.info/loopdata/2018-29/W/)
# getting loop data for race 30 in 2018 (https://www.racing-reference.info/loopdata/2018-30/W/)
# getting loop data for race 31 in 2018 (https://www.racing-reference.info/loopdata/2018-31/W/)
# getting loop data for race 32 in 2018 (https://www.racing-reference.info/loopdata/2018-32/W/)
# getting loop data for race 33 in 2018 (https://www.racing-reference.info/loopdata/2018-33/W/)
# getting loop data for race 34 in 2018 (https://www.racing-reference.info/loopdata/2018-34/W/)
# getting loop data for race 35 in 2018 (https://www.racing-reference.info/loopdata/2018-35/W/)
# getting loop data for race 36 in 2018 (https://www.racing-reference.info/loopdata/2018-36/W/)
# getting loop data for race 01 in 2019 (https://www.racing-reference.info/loopdata/2019-01/W/)
# getting loop data for race 02 in 2019 (https://www.racing-reference.info/loopdata/2019-02/W/)
# getting loop data for race 03 in 2019 (https://www.racing-reference.info/loopdata/2019-03/W/)
# getting loop data for race 04 in 2019 (https://www.racing-reference.info/loopdata/2019-04/W/)
# getting loop data for race 05 in 2019 (https://www.racing-reference.info/loopdata/2019-05/W/)
# getting loop data for race 06 in 2019 (https://www.racing-reference.info/loopdata/2019-06/W/)
# getting loop data for race 07 in 2019 (https://www.racing-reference.info/loopdata/2019-07/W/)
# getting loop data for race 08 in 2019 (https://www.racing-reference.info/loopdata/2019-08/W/)
# getting loop data for race 09 in 2019 (https://www.racing-reference.info/loopdata/2019-09/W/)
# getting loop data for race 10 in 2019 (https://www.racing-reference.info/loopdata/2019-10/W/)
# getting loop data for race 11 in 2019 (https://www.racing-reference.info/loopdata/2019-11/W/)
# getting loop data for race 12 in 2019 (https://www.racing-reference.info/loopdata/2019-12/W/)
# getting loop data for race 13 in 2019 (https://www.racing-reference.info/loopdata/2019-13/W/)
# getting loop data for race 14 in 2019 (https://www.racing-reference.info/loopdata/2019-14/W/)
# getting loop data for race 15 in 2019 (https://www.racing-reference.info/loopdata/2019-15/W/)
# getting loop data for race 16 in 2019 (https://www.racing-reference.info/loopdata/2019-16/W/)
# getting loop data for race 17 in 2019 (https://www.racing-reference.info/loopdata/2019-17/W/)
# getting loop data for race 18 in 2019 (https://www.racing-reference.info/loopdata/2019-18/W/)
# getting loop data for race 19 in 2019 (https://www.racing-reference.info/loopdata/2019-19/W/)
# getting loop data for race 20 in 2019 (https://www.racing-reference.info/loopdata/2019-20/W/)
# getting loop data for race 21 in 2019 (https://www.racing-reference.info/loopdata/2019-21/W/)
# getting loop data for race 22 in 2019 (https://www.racing-reference.info/loopdata/2019-22/W/)
# getting loop data for race 23 in 2019 (https://www.racing-reference.info/loopdata/2019-23/W/)
# getting loop data for race 24 in 2019 (https://www.racing-reference.info/loopdata/2019-24/W/)
# getting loop data for race 25 in 2019 (https://www.racing-reference.info/loopdata/2019-25/W/)
# getting loop data for race 26 in 2019 (https://www.racing-reference.info/loopdata/2019-26/W/)
# getting loop data for race 27 in 2019 (https://www.racing-reference.info/loopdata/2019-27/W/)
# getting loop data for race 28 in 2019 (https://www.racing-reference.info/loopdata/2019-28/W/)
# getting loop data for race 29 in 2019 (https://www.racing-reference.info/loopdata/2019-29/W/)
# getting loop data for race 30 in 2019 (https://www.racing-reference.info/loopdata/2019-30/W/)
# getting loop data for race 31 in 2019 (https://www.racing-reference.info/loopdata/2019-31/W/)
# getting loop data for race 32 in 2019 (https://www.racing-reference.info/loopdata/2019-32/W/)
# getting loop data for race 33 in 2019 (https://www.racing-reference.info/loopdata/2019-33/W/)
# getting loop data for race 34 in 2019 (https://www.racing-reference.info/loopdata/2019-34/W/)
# getting loop data for race 35 in 2019 (https://www.racing-reference.info/loopdata/2019-35/W/)
# getting loop data for race 36 in 2019 (https://www.racing-reference.info/loopdata/2019-36/W/)
# getting loop data for race 01 in 2020 (https://www.racing-reference.info/loopdata/2020-01/W/)
# getting loop data for race 02 in 2020 (https://www.racing-reference.info/loopdata/2020-02/W/)
# getting loop data for race 03 in 2020 (https://www.racing-reference.info/loopdata/2020-03/W/)
# getting loop data for race 04 in 2020 (https://www.racing-reference.info/loopdata/2020-04/W/)
# getting loop data for race 05 in 2020 (https://www.racing-reference.info/loopdata/2020-05/W/)
# getting loop data for race 06 in 2020 (https://www.racing-reference.info/loopdata/2020-06/W/)
# getting loop data for race 07 in 2020 (https://www.racing-reference.info/loopdata/2020-07/W/)
# getting loop data for race 08 in 2020 (https://www.racing-reference.info/loopdata/2020-08/W/)
# getting loop data for race 09 in 2020 (https://www.racing-reference.info/loopdata/2020-09/W/)
# getting loop data for race 10 in 2020 (https://www.racing-reference.info/loopdata/2020-10/W/)
# getting loop data for race 11 in 2020 (https://www.racing-reference.info/loopdata/2020-11/W/)
# getting loop data for race 12 in 2020 (https://www.racing-reference.info/loopdata/2020-12/W/)
# getting loop data for race 13 in 2020 (https://www.racing-reference.info/loopdata/2020-13/W/)
# getting loop data for race 14 in 2020 (https://www.racing-reference.info/loopdata/2020-14/W/)
# getting loop data for race 15 in 2020 (https://www.racing-reference.info/loopdata/2020-15/W/)
# getting loop data for race 16 in 2020 (https://www.racing-reference.info/loopdata/2020-16/W/)
# getting loop data for race 17 in 2020 (https://www.racing-reference.info/loopdata/2020-17/W/)
# getting loop data for race 18 in 2020 (https://www.racing-reference.info/loopdata/2020-18/W/)
# getting loop data for race 19 in 2020 (https://www.racing-reference.info/loopdata/2020-19/W/)
# getting loop data for race 20 in 2020 (https://www.racing-reference.info/loopdata/2020-20/W/)
# getting loop data for race 21 in 2020 (https://www.racing-reference.info/loopdata/2020-21/W/)
# getting loop data for race 22 in 2020 (https://www.racing-reference.info/loopdata/2020-22/W/)
# getting loop data for race 23 in 2020 (https://www.racing-reference.info/loopdata/2020-23/W/)
# getting loop data for race 24 in 2020 (https://www.racing-reference.info/loopdata/2020-24/W/)
# getting loop data for race 25 in 2020 (https://www.racing-reference.info/loopdata/2020-25/W/)
# getting loop data for race 26 in 2020 (https://www.racing-reference.info/loopdata/2020-26/W/)
# getting loop data for race 27 in 2020 (https://www.racing-reference.info/loopdata/2020-27/W/)
# getting loop data for race 28 in 2020 (https://www.racing-reference.info/loopdata/2020-28/W/)
# getting loop data for race 29 in 2020 (https://www.racing-reference.info/loopdata/2020-29/W/)
# getting loop data for race 30 in 2020 (https://www.racing-reference.info/loopdata/2020-30/W/)
# getting loop data for race 31 in 2020 (https://www.racing-reference.info/loopdata/2020-31/W/)
# getting loop data for race 32 in 2020 (https://www.racing-reference.info/loopdata/2020-32/W/)
# getting loop data for race 33 in 2020 (https://www.racing-reference.info/loopdata/2020-33/W/)
# getting loop data for race 34 in 2020 (https://www.racing-reference.info/loopdata/2020-34/W/)
# getting loop data for race 35 in 2020 (https://www.racing-reference.info/loopdata/2020-35/W/)
# getting loop data for race 36 in 2020 (https://www.racing-reference.info/loopdata/2020-36/W/)
# getting loop data for race 01 in 2021 (https://www.racing-reference.info/loopdata/2021-01/W/)
# getting loop data for race 02 in 2021 (https://www.racing-reference.info/loopdata/2021-02/W/)
# getting loop data for race 03 in 2021 (https://www.racing-reference.info/loopdata/2021-03/W/)
# getting loop data for race 04 in 2021 (https://www.racing-reference.info/loopdata/2021-04/W/)
# getting loop data for race 05 in 2021 (https://www.racing-reference.info/loopdata/2021-05/W/)
# getting loop data for race 06 in 2021 (https://www.racing-reference.info/loopdata/2021-06/W/)
# getting loop data for race 07 in 2021 (https://www.racing-reference.info/loopdata/2021-07/W/)
# getting loop data for race 08 in 2021 (https://www.racing-reference.info/loopdata/2021-08/W/)
# getting loop data for race 09 in 2021 (https://www.racing-reference.info/loopdata/2021-09/W/)
# getting loop data for race 10 in 2021 (https://www.racing-reference.info/loopdata/2021-10/W/)
# getting loop data for race 11 in 2021 (https://www.racing-reference.info/loopdata/2021-11/W/)
# getting loop data for race 12 in 2021 (https://www.racing-reference.info/loopdata/2021-12/W/)
# getting loop data for race 13 in 2021 (https://www.racing-reference.info/loopdata/2021-13/W/)
# getting loop data for race 14 in 2021 (https://www.racing-reference.info/loopdata/2021-14/W/)
# getting loop data for race 15 in 2021 (https://www.racing-reference.info/loopdata/2021-15/W/)
# getting loop data for race 16 in 2021 (https://www.racing-reference.info/loopdata/2021-16/W/)
# getting loop data for race 17 in 2021 (https://www.racing-reference.info/loopdata/2021-17/W/)
# getting loop data for race 18 in 2021 (https://www.racing-reference.info/loopdata/2021-18/W/)
# getting loop data for race 19 in 2021 (https://www.racing-reference.info/loopdata/2021-19/W/)
# getting loop data for race 20 in 2021 (https://www.racing-reference.info/loopdata/2021-20/W/)
# getting loop data for race 21 in 2021 (https://www.racing-reference.info/loopdata/2021-21/W/)
# getting loop data for race 22 in 2021 (https://www.racing-reference.info/loopdata/2021-22/W/)
# getting loop data for race 23 in 2021 (https://www.racing-reference.info/loopdata/2021-23/W/)
# getting loop data for race 24 in 2021 (https://www.racing-reference.info/loopdata/2021-24/W/)
# getting loop data for race 25 in 2021 (https://www.racing-reference.info/loopdata/2021-25/W/)
# getting loop data for race 26 in 2021 (https://www.racing-reference.info/loopdata/2021-26/W/)
# getting loop data for race 27 in 2021 (https://www.racing-reference.info/loopdata/2021-27/W/)
# getting loop data for race 28 in 2021 (https://www.racing-reference.info/loopdata/2021-28/W/)
# getting loop data for race 29 in 2021 (https://www.racing-reference.info/loopdata/2021-29/W/)
# getting loop data for race 30 in 2021 (https://www.racing-reference.info/loopdata/2021-30/W/)
# getting loop data for race 31 in 2021 (https://www.racing-reference.info/loopdata/2021-31/W/)
# getting loop data for race 32 in 2021 (https://www.racing-reference.info/loopdata/2021-32/W/)
# getting loop data for race 33 in 2021 (https://www.racing-reference.info/loopdata/2021-33/W/)
# getting loop data for race 34 in 2021 (https://www.racing-reference.info/loopdata/2021-34/W/)
# getting loop data for race 35 in 2021 (https://www.racing-reference.info/loopdata/2021-35/W/)
# getting loop data for race 36 in 2021 (https://www.racing-reference.info/loopdata/2021-36/W/)
# getting loop data for race 01 in 2022 (https://www.racing-reference.info/loopdata/2022-01/W/)
# getting loop data for race 02 in 2022 (https://www.racing-reference.info/loopdata/2022-02/W/)
# getting loop data for race 03 in 2022 (https://www.racing-reference.info/loopdata/2022-03/W/)
# getting loop data for race 04 in 2022 (https://www.racing-reference.info/loopdata/2022-04/W/)
# getting loop data for race 05 in 2022 (https://www.racing-reference.info/loopdata/2022-05/W/)
# getting loop data for race 06 in 2022 (https://www.racing-reference.info/loopdata/2022-06/W/)
# getting loop data for race 07 in 2022 (https://www.racing-reference.info/loopdata/2022-07/W/)
# getting loop data for race 08 in 2022 (https://www.racing-reference.info/loopdata/2022-08/W/)
# getting loop data for race 09 in 2022 (https://www.racing-reference.info/loopdata/2022-09/W/)
# getting loop data for race 10 in 2022 (https://www.racing-reference.info/loopdata/2022-10/W/)
# getting loop data for race 11 in 2022 (https://www.racing-reference.info/loopdata/2022-11/W/)
# getting loop data for race 12 in 2022 (https://www.racing-reference.info/loopdata/2022-12/W/)
# getting loop data for race 13 in 2022 (https://www.racing-reference.info/loopdata/2022-13/W/)
# getting loop data for race 14 in 2022 (https://www.racing-reference.info/loopdata/2022-14/W/)
# getting loop data for race 15 in 2022 (https://www.racing-reference.info/loopdata/2022-15/W/)
# getting loop data for race 16 in 2022 (https://www.racing-reference.info/loopdata/2022-16/W/)
# getting loop data for race 17 in 2022 (https://www.racing-reference.info/loopdata/2022-17/W/)
# getting loop data for race 18 in 2022 (https://www.racing-reference.info/loopdata/2022-18/W/)
# getting loop data for race 19 in 2022 (https://www.racing-reference.info/loopdata/2022-19/W/)
# getting loop data for race 20 in 2022 (https://www.racing-reference.info/loopdata/2022-20/W/)
# getting loop data for race 21 in 2022 (https://www.racing-reference.info/loopdata/2022-21/W/)
# getting loop data for race 22 in 2022 (https://www.racing-reference.info/loopdata/2022-22/W/)
# getting loop data for race 23 in 2022 (https://www.racing-reference.info/loopdata/2022-23/W/)
# getting loop data for race 24 in 2022 (https://www.racing-reference.info/loopdata/2022-24/W/)
# getting loop data for race 25 in 2022 (https://www.racing-reference.info/loopdata/2022-25/W/)
# getting loop data for race 26 in 2022 (https://www.racing-reference.info/loopdata/2022-26/W/)
# getting loop data for race 27 in 2022 (https://www.racing-reference.info/loopdata/2022-27/W/)
# getting loop data for race 28 in 2022 (https://www.racing-reference.info/loopdata/2022-28/W/)
# getting loop data for race 29 in 2022 (https://www.racing-reference.info/loopdata/2022-29/W/)
# getting loop data for race 30 in 2022 (https://www.racing-reference.info/loopdata/2022-30/W/)
# getting loop data for race 31 in 2022 (https://www.racing-reference.info/loopdata/2022-31/W/)
# getting loop data for race 32 in 2022 (https://www.racing-reference.info/loopdata/2022-32/W/)
# getting loop data for race 33 in 2022 (https://www.racing-reference.info/loopdata/2022-33/W/)
# getting loop data for race 34 in 2022 (https://www.racing-reference.info/loopdata/2022-34/W/)
# getting loop data for race 35 in 2022 (https://www.racing-reference.info/loopdata/2022-35/W/)
# getting loop data for race 36 in 2022 (https://www.racing-reference.info/loopdata/2022-36/W/)

# %%
loopdata_df = pd.concat(frames, axis = 0)

# %%
loopdata_df
# Out:
#                   Driver Start Mid Race Finish High Pos. Low Pos. Avg. Pos.  \
# 0             Kurt Busch     8       23      1         1       37        12
# 1            Ryan Blaney    36       26      2         1       38         9
# 2      A.J. Allmendinger    38       15      3         1       38        18
# 3          Aric Almirola    13       13      4         1       31        15
# 4            Paul Menard    33       35      5         3       37        16
# ..                   ...   ...      ...    ...       ...      ...       ...
# 31  Ricky Stenhouse, Jr.    29       34     32        24       34        32
# 32      Garrett Smithley    35       35     33        33       36        35
# 33           Alex Bowman    24       28     34         1       34        21
# 34       Brad Keselowski    18       21     35        14       30        25
# 35        Landon Cassill    36       36     36        30       36        35
#
#    Pass Diff. Green Flag Passes Green Flag Times Passed Quality Passes  \
# 0          17               248                     231            181
# 1          18               315                     297            240
# 2          53               250                     197            105
# 3          -9               279                     288            124
# 4          14               303                     289            172
# ..        ...               ...                     ...            ...
# 31          2                28                      26              0
# 32          0                 5                       5              0
# 33          4               108                     104              9
# 34        -13                58                      71              3
# 35          4                 9                       5              0
#
#    Pct. Quality Passes Fastest Lap Top 15 Laps Pct. Top 15 Laps Laps Led  \
# 0                 73.0           5         133             66.5        1
# 1                 76.2          11         166             83.0        2
# 2                 42.0           6          75             37.5        2
# 3                 44.4           7          96             48.0        2
# 4                 56.8           8         109             54.5        0
# ..                 ...         ...         ...              ...      ...
# 31                 0.0           0           0              0.0        0
# 32                 0.0           0           0              0.0        0
# 33                 8.3          11          27              8.9        1
# 34                 5.2           0           8              3.0        0
# 35                 0.0           0           0              0.0        0
#
#    Pct. Laps Led Total Laps DRIVER RATING  race_ID
# 0            0.5        200         107.0        1
# 1            1.0        200         106.2        1
# 2            1.0        200          80.5        1
# 3            1.0        200          82.9        1
# 4            0.0        200          92.9        1
# ..           ...        ...           ...      ...
# 31           0.0        307          32.5      216
# 32           0.0        304          25.5      216
# 33           0.3        304          55.8      216
# 34           0.0        270          43.7      216
# 35           0.0         84          28.0      216
#
# [8312 rows x 20 columns]

# %%
loopdata_df.to_csv('data/loopdata_2017-2022.csv')
